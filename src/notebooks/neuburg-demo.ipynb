# %% [markdown]
# # Neuburg Demo Jugendtrefen

# %% [markdown]
# ## infDB python package

# %%
# Install inDB python handler
# %pip install infdb

# Install other python packages
# %pip install geopandas
# %pip install branca folium matplotlib mapclassify # gpd.explore()

# %%
import os
import geopandas as gpd
from infdb import InfDB

# %%
# Load InfDB handler
infdbhandler = InfDB(tool_name="demo")

# Database connection
infdbclient_citydb = infdbhandler.connect(db_name="citydb")

# Logger setup
infdblog = infdbhandler.get_log()

# Start message
infdblog.info(f"Starting {infdbhandler.get_toolname()} tool")

# %%
# Setup database engine
engine = infdbclient_citydb.get_db_engine()
sql = "SELECT * FROM kwp.buildings_heat_demand"
gdf_buildings = gpd.read_postgis(sql, engine,  geom_col='geom')
gdf_buildings.head()

# %%
gdf_buildings.explore()

# %%
sql = "SELECT * FROM kwp.ways_heat_demand"
gdf_ways = gpd.read_postgis(sql, engine,  geom_col='geom')
gdf_ways.head()

# %%
gdf_ways.explore()

# %%
m = gdf_buildings.explore(column="demand_heating")
gdf_ways.explore(m=m, column="demand_per_length")

# %% [markdown]
# # Connection without infdb_package

# %%
from sqlalchemy import create_engine
import geopandas
db_connection_url = "postgresql://citydb_user:infdb@host.docker.internal:54329/citydb" #docker internal connection: citydb:5432
con = create_engine(db_connection_url)
sql = "SELECT * FROM kwp.buildings_heat_demand"
gdf_buildings = geopandas.read_postgis(sql, con)

# %%
gdf_buildings.explore()

# %% [markdown]
# # Webserver

# %%
from http.server import HTTPServer, SimpleHTTPRequestHandler

# Save to HTML
m.save("index.html")

# Webserver
httpd = HTTPServer(("0.0.0.0", 123), SimpleHTTPRequestHandler)
print("Serving at http://localhost:123")
httpd.serve_forever()
